# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bossbase/boss_256_0.4/cover/4353.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7968.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6490.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5511.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6262.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2664.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8419.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2539.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5703.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1231.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1017.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4803.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7197.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2437.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7530.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3217.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5695.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8565.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6441.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6692.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5106.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5590.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3207.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2015.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2300.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2673.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2823.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3765.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1522.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4747.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6720.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6811.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3824.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7726.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6131.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4358.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2064.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6456.png
# /kaggle/input/bossbase/boss_256_0.4/cover/641.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7324.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1088.png
# /kaggle/input/bossbase/boss_256_0.4/cover/173.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5100.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7863.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2851.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6875.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8414.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8841.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2448.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7992.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7290.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7334.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1746.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1958.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1479.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7418.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8426.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6859.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7134.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7633.png
# /kaggle/input/bossbase/boss_256_0.4/cover/815.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4352.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3448.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1794.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1727.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7780.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8987.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1684.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4685.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4649.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7236.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5184.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1814.png
# /kaggle/input/bossbase/boss_256_0.4/cover/491.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2982.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8281.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2276.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1457.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3152.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4319.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8669.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1924.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4805.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1084.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5109.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7714.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8343.png
# /kaggle/input/bossbase/boss_256_0.4/cover/718.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3722.png
# /kaggle/input/bossbase/boss_256_0.4/cover/709.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2690.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6683.png
# /kaggle/input/bossbase/boss_256_0.4/cover/889.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8062.png
# /kaggle/input/bossbase/boss_256_0.4/cover/379.png
# /kaggle/input/bossbase/boss_256_0.4/cover/780.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7257.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3244.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8514.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6595.png
# /kaggle/input/bossbase/boss_256_0.4/cover/248.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7621.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8947.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8231.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5073.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1680.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1675.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2619.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6299.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6971.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4023.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2273.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4800.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5028.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7432.png
# /kaggle/input/bossbase/boss_256_0.4/cover/94.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7119.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2969.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3379.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2772.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7105.png
# /kaggle/input/bossbase/boss_256_0.4/cover/480.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8794.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7753.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6645.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3550.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5567.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2256.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5918.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1145.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6978.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7395.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3295.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5950.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2021.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1944.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6423.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3569.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7166.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6630.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6536.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3685.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7592.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8685.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7601.png
# /kaggle/input/bossbase/boss_256_0.4/cover/236.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3890.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8526.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6255.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1012.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2970.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2518.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2176.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8906.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1343.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6014.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8790.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2347.png
# /kaggle/input/bossbase/boss_256_0.4/cover/771.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7488.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2884.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4770.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2631.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6199.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7079.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8811.png
# /kaggle/input/bossbase/boss_256_0.4/cover/675.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7360.png
# /kaggle/input/bossbase/boss_256_0.4/cover/340.png
# /kaggle/input/bossbase/boss_256_0.4/cover/48.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3952.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6059.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2525.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3012.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1948.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4518.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1878.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7302.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7316.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2211.png
# /kaggle/input/bossbase/boss_256_0.4/cover/513.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2947.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7269.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3917.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2976.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8146.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3510.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1037.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8958.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4511.png
# /kaggle/input/bossbase/boss_256_0.4/cover/677.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5593.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6687.png
# /kaggle/input/bossbase/boss_256_0.4/cover/350.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2009.png
# /kaggle/input/bossbase/boss_256_0.4/cover/761.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1258.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8639.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3362.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8251.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8897.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4792.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4916.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2565.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7136.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3363.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8302.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6632.png
# /kaggle/input/bossbase/boss_256_0.4/cover/314.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5197.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3544.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1023.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5595.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8962.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1337.png
# /kaggle/input/bossbase/boss_256_0.4/cover/655.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8536.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8970.png
# /kaggle/input/bossbase/boss_256_0.4/cover/227.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5816.png
# /kaggle/input/bossbase/boss_256_0.4/cover/762.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8658.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2803.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7255.png
# /kaggle/input/bossbase/boss_256_0.4/cover/726.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8377.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8930.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2199.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5858.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5543.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1630.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8569.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5898.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8660.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5831.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2920.png
# /kaggle/input/bossbase/boss_256_0.4/cover/238.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3728.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3070.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6910.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8364.png
# /kaggle/input/bossbase/boss_256_0.4/cover/61.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2731.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6158.png
# /kaggle/input/bossbase/boss_256_0.4/cover/377.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5391.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8793.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4554.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6295.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8295.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7349.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7635.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4418.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8610.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1961.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7331.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1798.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7608.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8473.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4864.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2324.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6626.png
# /kaggle/input/bossbase/boss_256_0.4/cover/581.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1782.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6887.png
# /kaggle/input/bossbase/boss_256_0.4/cover/222.png
# /kaggle/input/bossbase/boss_256_0.4/cover/330.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6851.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5038.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2742.png
# /kaggle/input/bossbase/boss_256_0.4/cover/511.png
# /kaggle/input/bossbase/boss_256_0.4/cover/579.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6337.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5957.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8507.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6812.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6802.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7975.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4127.png
# /kaggle/input/bossbase/boss_256_0.4/cover/278.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4236.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2146.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6863.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1863.png
# /kaggle/input/bossbase/boss_256_0.4/cover/927.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7275.png
# /kaggle/input/bossbase/boss_256_0.4/cover/303.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3921.png
# /kaggle/input/bossbase/boss_256_0.4/cover/37.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8454.png
# /kaggle/input/bossbase/boss_256_0.4/cover/231.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1048.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2367.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8440.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6852.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2559.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5908.png
# /kaggle/input/bossbase/boss_256_0.4/cover/645.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2270.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1703.png
# /kaggle/input/bossbase/boss_256_0.4/cover/348.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5731.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6108.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3959.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6587.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7681.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5501.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5802.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3372.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4444.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5620.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7490.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4326.png
# /kaggle/input/bossbase/boss_256_0.4/cover/449.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3960.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3602.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2718.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5629.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7791.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5378.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3924.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5468.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6509.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4303.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6258.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6408.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2779.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4738.png
# /kaggle/input/bossbase/boss_256_0.4/cover/353.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4463.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7155.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7124.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3777.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5694.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7050.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7072.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6663.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8601.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4869.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7097.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6122.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7657.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2645.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7921.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7794.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6143.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7825.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3539.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3884.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7266.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7777.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5414.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5461.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3375.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3770.png
# /kaggle/input/bossbase/boss_256_0.4/cover/621.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5422.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8451.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2134.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3351.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5361.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5518.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8860.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3450.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6375.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7688.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6033.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7965.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7408.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4699.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1726.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7487.png
# /kaggle/input/bossbase/boss_256_0.4/cover/148.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7675.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5612.png
# /kaggle/input/bossbase/boss_256_0.4/cover/990.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2844.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7955.png
# /kaggle/input/bossbase/boss_256_0.4/cover/403.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3632.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2661.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3622.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4298.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3702.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3068.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6991.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1590.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5174.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8299.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8320.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1995.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2121.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8816.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6450.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8354.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3366.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3709.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3296.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5993.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8201.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1855.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3107.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4847.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8956.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4761.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1813.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6506.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1000.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8594.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4957.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5674.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7708.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2346.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4309.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2269.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5657.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7456.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4226.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1604.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4478.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5947.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6205.png
# /kaggle/input/bossbase/boss_256_0.4/cover/352.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8084.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2522.png
# /kaggle/input/bossbase/boss_256_0.4/cover/35.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2302.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3102.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8996.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8661.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4540.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3637.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6171.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6619.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5448.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8951.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3440.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2030.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6729.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3748.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3406.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5130.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5342.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8371.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6317.png
# /kaggle/input/bossbase/boss_256_0.4/cover/232.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5503.png
# /kaggle/input/bossbase/boss_256_0.4/cover/817.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6921.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7573.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1827.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7068.png
# /kaggle/input/bossbase/boss_256_0.4/cover/334.png
# /kaggle/input/bossbase/boss_256_0.4/cover/177.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8026.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8724.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2533.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2637.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7823.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8269.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7477.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8925.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4626.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2990.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1081.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8336.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5681.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6476.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3262.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7001.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6335.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8384.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7724.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4530.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8032.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1780.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3554.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3531.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7884.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1992.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5364.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7541.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2058.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7788.png
# /kaggle/input/bossbase/boss_256_0.4/cover/142.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5960.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2365.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5432.png
# /kaggle/input/bossbase/boss_256_0.4/cover/834.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6021.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3002.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1176.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1914.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5959.png
# /kaggle/input/bossbase/boss_256_0.4/cover/754.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3655.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8461.png
# /kaggle/input/bossbase/boss_256_0.4/cover/407.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3047.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2767.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7735.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6958.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2978.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6388.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6241.png
# /kaggle/input/bossbase/boss_256_0.4/cover/104.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7506.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4641.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2013.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4846.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3561.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1690.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5962.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1413.png
# /kaggle/input/bossbase/boss_256_0.4/cover/384.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2011.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4852.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8915.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4208.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5093.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4776.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4582.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1670.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7586.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8551.png
# /kaggle/input/bossbase/boss_256_0.4/cover/376.png
# /kaggle/input/bossbase/boss_256_0.4/cover/543.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1312.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5845.png
# /kaggle/input/bossbase/boss_256_0.4/cover/737.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4661.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6166.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7075.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1156.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4110.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3220.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6563.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1004.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4261.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8348.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8810.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8821.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8845.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8735.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2069.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8344.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2675.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8247.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8954.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6759.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8028.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4175.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3692.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3052.png
# /kaggle/input/bossbase/boss_256_0.4/cover/133.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8489.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4070.png
# /kaggle/input/bossbase/boss_256_0.4/cover/70.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1754.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6856.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7195.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1529.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7202.png
# /kaggle/input/bossbase/boss_256_0.4/cover/162.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6385.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5547.png
# /kaggle/input/bossbase/boss_256_0.4/cover/419.png
# /kaggle/input/bossbase/boss_256_0.4/cover/951.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1705.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6857.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4052.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2169.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2410.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7480.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4442.png
# /kaggle/input/bossbase/boss_256_0.4/cover/940.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3058.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4296.png
# /kaggle/input/bossbase/boss_256_0.4/cover/517.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1032.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6581.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6387.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6599.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6248.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7024.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6633.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7766.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8477.png
# /kaggle/input/bossbase/boss_256_0.4/cover/398.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7550.png
# /kaggle/input/bossbase/boss_256_0.4/cover/634.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4484.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3634.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1513.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7985.png
# /kaggle/input/bossbase/boss_256_0.4/cover/186.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6583.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7851.png
# /kaggle/input/bossbase/boss_256_0.4/cover/778.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8277.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8261.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8752.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5437.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6713.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3030.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8471.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7982.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3189.png
# /kaggle/input/bossbase/boss_256_0.4/cover/73.png
# /kaggle/input/bossbase/boss_256_0.4/cover/870.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4350.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6018.png
# /kaggle/input/bossbase/boss_256_0.4/cover/933.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7088.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2741.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2513.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3715.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8655.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1633.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3712.png
# /kaggle/input/bossbase/boss_256_0.4/cover/92.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8656.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5989.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8020.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6727.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7351.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1328.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4914.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8677.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8715.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7694.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2182.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2381.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1989.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6138.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8878.png
# /kaggle/input/bossbase/boss_256_0.4/cover/542.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2376.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5340.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2136.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4771.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4671.png
# /kaggle/input/bossbase/boss_256_0.4/cover/766.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2003.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4033.png
# /kaggle/input/bossbase/boss_256_0.4/cover/315.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7312.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4809.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7274.png
# /kaggle/input/bossbase/boss_256_0.4/cover/436.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8127.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6970.png
# /kaggle/input/bossbase/boss_256_0.4/cover/359.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4985.png
# /kaggle/input/bossbase/boss_256_0.4/cover/261.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3469.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8104.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4677.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5790.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5598.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1214.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7564.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7820.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4670.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1931.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8147.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7685.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8941.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5723.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1673.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3697.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2051.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1532.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1820.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7722.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7527.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3497.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6320.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2537.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1918.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4051.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8301.png
# /kaggle/input/bossbase/boss_256_0.4/cover/901.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6008.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5485.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3804.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3061.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5781.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1096.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2430.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7445.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4578.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2829.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5976.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8532.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3568.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2893.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4494.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7556.png
# /kaggle/input/bossbase/boss_256_0.4/cover/153.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5023.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1578.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3205.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3403.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1954.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8141.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7416.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8614.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6397.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1500.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4910.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5173.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1846.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2462.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1959.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5488.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2218.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2902.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7111.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7666.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4990.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2099.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6555.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3184.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6207.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4277.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1320.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7862.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3920.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7945.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6144.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4563.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8288.png
# /kaggle/input/bossbase/boss_256_0.4/cover/167.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1348.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2640.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5741.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6647.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6376.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6275.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7157.png
# /kaggle/input/bossbase/boss_256_0.4/cover/628.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7358.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7453.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6222.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3053.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2041.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3736.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3243.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6888.png
# /kaggle/input/bossbase/boss_256_0.4/cover/506.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2156.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3341.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6130.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1147.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1375.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1452.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7513.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5934.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7216.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2094.png
# /kaggle/input/bossbase/boss_256_0.4/cover/441.png
# /kaggle/input/bossbase/boss_256_0.4/cover/928.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7392.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5584.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4598.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4536.png
# /kaggle/input/bossbase/boss_256_0.4/cover/562.png
# /kaggle/input/bossbase/boss_256_0.4/cover/681.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5129.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2668.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3659.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2582.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1266.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1542.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5298.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4552.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5399.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4423.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8574.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5707.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3174.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7099.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2526.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1206.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3028.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5151.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1064.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6321.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4228.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7588.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3415.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6612.png
# /kaggle/input/bossbase/boss_256_0.4/cover/204.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6938.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8629.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7838.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6686.png
# /kaggle/input/bossbase/boss_256_0.4/cover/646.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1179.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5039.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6682.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2233.png
# /kaggle/input/bossbase/boss_256_0.4/cover/75.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8615.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1128.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8913.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5961.png
# /kaggle/input/bossbase/boss_256_0.4/cover/296.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2184.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7605.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1494.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5017.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7300.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5091.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2388.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3650.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5417.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1364.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1334.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1576.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1072.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2832.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8608.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4388.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4959.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7175.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6807.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1123.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1808.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3283.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2801.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4026.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6953.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4925.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6839.png
# /kaggle/input/bossbase/boss_256_0.4/cover/744.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2428.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1314.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8509.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4687.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6406.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3098.png
# /kaggle/input/bossbase/boss_256_0.4/cover/538.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1301.png
# /kaggle/input/bossbase/boss_256_0.4/cover/651.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7572.png
# /kaggle/input/bossbase/boss_256_0.4/cover/899.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6432.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6567.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5542.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3172.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6860.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8434.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4652.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6606.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1907.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3255.png
# /kaggle/input/bossbase/boss_256_0.4/cover/270.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2607.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4839.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3082.png
# /kaggle/input/bossbase/boss_256_0.4/cover/89.png
# /kaggle/input/bossbase/boss_256_0.4/cover/385.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8228.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3628.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2096.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3645.png
# /kaggle/input/bossbase/boss_256_0.4/cover/768.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4675.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8237.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4381.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8859.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7516.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3833.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6889.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7019.png
# /kaggle/input/bossbase/boss_256_0.4/cover/872.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8840.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5413.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5224.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7102.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6098.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4902.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5933.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4269.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5238.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7833.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2079.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8556.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4196.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5065.png
# /kaggle/input/bossbase/boss_256_0.4/cover/338.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3025.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3478.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3949.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4003.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7368.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5289.png
# /kaggle/input/bossbase/boss_256_0.4/cover/333.png
# /kaggle/input/bossbase/boss_256_0.4/cover/164.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5069.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5121.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1168.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5740.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1118.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4740.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4782.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1867.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6751.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6192.png
# /kaggle/input/bossbase/boss_256_0.4/cover/752.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4155.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3831.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5516.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2795.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8885.png
# /kaggle/input/bossbase/boss_256_0.4/cover/550.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1326.png
# /kaggle/input/bossbase/boss_256_0.4/cover/521.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4334.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4493.png
# /kaggle/input/bossbase/boss_256_0.4/cover/6146.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1275.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8784.png
# /kaggle/input/bossbase/boss_256_0.4/cover/3599.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2355.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5905.png
# /kaggle/input/bossbase/boss_256_0.4/cover/2143.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8466.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5574.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1789.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5927.png
# /kaggle/input/bossbase/boss_256_0.4/cover/11.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1668.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5568.png
# /kaggle/input/bossbase/boss_256_0.4/cover/1036.png
# /kaggle/input/bossbase/boss_256_0.4/cover/5101.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7396.png
# /kaggle/input/bossbase/boss_256_0.4/cover/4466.png
# /kaggle/input/bossbase/boss_256_0.4/cover/615.png
# /kaggle/input/bossbase/boss_256_0.4/cover/8964.png
# /kaggle/input/bossbase/boss_256_0.4/cover/7629.png
# ...
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9116.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9437.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9589.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9379.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9630.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9615.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9747.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9111.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9035.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9322.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9433.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9765.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9134.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9731.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9400.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9083.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9886.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9525.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9192.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9707.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9755.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9280.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9804.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9213.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9547.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9809.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9624.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9164.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9189.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9270.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9730.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9511.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9393.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9892.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9752.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9138.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9204.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9253.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9591.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9796.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9386.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9524.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9398.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9026.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9813.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9821.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9320.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9879.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9363.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9082.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9102.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9405.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9787.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9069.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9447.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9637.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9184.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9533.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9417.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9167.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9013.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9957.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9780.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9343.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9454.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9698.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9340.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9178.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9211.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9829.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9626.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9870.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9950.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9142.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9997.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9936.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9198.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9640.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9304.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9040.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9290.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9795.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9710.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9136.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9649.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9891.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9435.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9736.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9654.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9472.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9109.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9638.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9700.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9746.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9012.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9989.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9287.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9132.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9647.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9676.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9090.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9622.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9483.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9016.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9323.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9423.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9760.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9228.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/10000.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9148.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9037.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9990.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9007.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9140.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9235.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9131.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9776.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9084.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9848.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9488.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9491.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9798.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9168.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9721.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9732.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9907.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9440.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9161.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9801.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9226.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9091.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9628.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9344.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9436.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9371.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9548.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9349.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9908.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9269.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9585.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9153.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9711.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9399.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9506.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9604.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9790.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9224.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9735.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9274.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9593.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9885.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9089.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9712.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9112.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9761.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9413.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9594.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9561.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9909.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9658.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9448.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9974.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9966.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9687.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9984.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9574.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9911.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9207.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9617.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9197.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9705.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9034.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9209.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9660.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9078.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9365.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9295.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9127.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9651.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9252.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9181.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9800.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9958.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9474.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9220.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9903.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9185.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9655.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9697.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9242.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9166.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9087.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9849.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9690.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9025.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9464.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9778.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9750.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9227.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9928.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9664.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9470.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9208.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9769.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9097.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9607.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9328.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9407.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9479.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9346.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9836.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9643.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9312.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9232.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9143.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9727.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9941.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9520.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9963.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9419.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9599.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9992.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9720.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9575.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9055.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9499.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9418.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9439.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9661.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9401.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9744.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9921.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9842.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9543.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9079.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9807.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9996.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9645.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9135.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9289.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9567.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9642.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9759.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9683.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9358.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9580.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9639.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9751.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9066.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9106.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9159.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9517.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9383.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9578.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9065.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9937.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9709.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9536.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9505.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9299.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9582.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9149.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9844.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9276.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9972.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9831.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9632.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9729.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9492.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9350.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9612.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9653.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9249.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9500.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9912.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9934.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9843.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9817.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9074.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9170.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9532.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9579.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9285.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9704.png
# /kaggle/input/bossbase/boss_256_0.4_test/stego/9901.png

# %%
# Install required packages
# !pip install torch torchvision torchsummary pillow numpy scipy matplotlib scikit-learn tqdm

# Import libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix
import time
from tqdm import tqdm
import zipfile
import warnings
import shutil
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# Create directories
# !mkdir -p /kaggle/working/data/cover
# !mkdir -p /kaggle/working/data/stego
# !mkdir -p /kaggle/working/models
# !mkdir -p /kaggle/working/results

# ==================== DATASET ORGANIZATION ====================
def organize_bossbase_numerically(input_path, cover_output, stego_output):
    """
    Organize BOSSBase dataset using numerical ordering with proper naming
    """
    # Find all image files
    all_image_files = []
    for root, dirs, files in os.walk(input_path):
        for file in files:
            if file.endswith(('.pgm', '.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                all_image_files.append(os.path.join(root, file))
    
    print(f"Found {len(all_image_files)} image files")
    
    # Sort files numerically (not alphabetically)
    def numerical_sort_key(filepath):
        filename = os.path.basename(filepath)
        # Extract numbers from filename
        numbers = ''.join(filter(str.isdigit, filename))
        return int(numbers) if numbers else 0
    
    all_image_files.sort(key=numerical_sort_key)
    
    # Split files equally - first half as cover, second half as stego
    half_point = len(all_image_files) // 2
    cover_files = all_image_files[:half_point]
    stego_files = all_image_files[half_point:2*half_point]  # Ensure equal length
    
    print(f"Split into {len(cover_files)} cover and {len(stego_files)} stego images")
    
    # Clear existing directories
    shutil.rmtree(cover_output, ignore_errors=True)
    shutil.rmtree(stego_output, ignore_errors=True)
    os.makedirs(cover_output, exist_ok=True)
    os.makedirs(stego_output, exist_ok=True)
    
    # Copy cover images with consistent naming
    for i, img_path in enumerate(cover_files):
        filename = f"{i+1:05d}.png"  # Format as 00001.png, 00002.png, etc.
        destination = os.path.join(cover_output, filename)
        # Copy and convert if needed
        img = Image.open(img_path).convert('RGB')
        img.save(destination)
    
    # Copy stego images with consistent naming (same as cover)
    for i, img_path in enumerate(stego_files):
        filename = f"{i+1:05d}.png"  # Same naming convention as cover
        destination = os.path.join(stego_output, filename)
        img = Image.open(img_path).convert('RGB')
        img.save(destination)
    
    print(f"Organized {len(cover_files)} cover images and {len(stego_files)} stego images")
    return len(cover_files), len(stego_files)

# Organize the dataset
dataset_path = '/kaggle/input/bossbase'
cover_dir = '/kaggle/working/data/cover'
stego_dir = '/kaggle/working/data/stego'

cover_count, stego_count = organize_bossbase_numerically(dataset_path, cover_dir, stego_dir)

# Check the results
print("\nAfter organization:")
print(f"Cover images: {len(os.listdir(cover_dir))}")
print(f"Stego images: {len(os.listdir(stego_dir))}")

print("\nSample cover files:")
cover_files = sorted(os.listdir(cover_dir))
for f in cover_files[:5]:
    print(f"  {f}")

print("\nSample stego files:")
stego_files = sorted(os.listdir(stego_dir))
for f in stego_files[:5]:
    print(f"  {f}")

# Create simple 1:1 mapping (same filenames)
stego_to_cover_map = {}
for filename in cover_files:
    stego_to_cover_map[filename] = filename  # Same filename for both

print(f"\nCreated mapping for {len(stego_to_cover_map)} image pairs")
print("Sample mappings:")
for i, (cover, stego) in enumerate(list(stego_to_cover_map.items())[:5]):
    print(f"  {cover} → {stego}")

# Verify mapping is correct
print("\nVerifying mapping...")
all_good = True
for cover_file in cover_files[:10]:  # Check first 10
    stego_file = stego_to_cover_map[cover_file]
    if cover_file != stego_file:
        print(f"ERROR: {cover_file} → {stego_file}")
        all_good = False
    else:
        print(f"✓ {cover_file} → {stego_file}")

if all_good:
    print("✓ All mappings are correct!")
else:
    print("✗ Some mappings are incorrect!")

# ==================== SIMPLIFIED MODEL FOR TESTING ====================
print("\n" + "="*60)
print("CREATING SIMPLIFIED MODEL FOR TESTING")
print("="*60)

# Simplified Residual Feature Extractor
class SimpleResidualFeatureExtractor(nn.Module):
    def _init_(self):
        super(SimpleResidualFeatureExtractor, self)._init_()
        # Simple horizontal and vertical filters only
        self.horizontal_filter = nn.Conv2d(1, 1, kernel_size=3, padding=1, bias=False)
        self.vertical_filter = nn.Conv2d(1, 1, kernel_size=3, padding=1, bias=False)
        
        # Initialize with simple edge detection filters
        self.horizontal_filter.weight.data = torch.FloatTensor([[[[0, 0, 0], [-1, 0, 1], [0, 0, 0]]]])
        self.vertical_filter.weight.data = torch.FloatTensor([[[[0, -1, 0], [0, 0, 0], [0, 1, 0]]]])
        
    def forward(self, x):
        if x.shape[1] == 3:
            x_gray = 0.299 * x[:, 0:1, :, :] + 0.587 * x[:, 1:2, :, :] + 0.114 * x[:, 2:3, :, :]
        else:
            x_gray = x
        
        horizontal = self.horizontal_filter(x_gray)
        vertical = self.vertical_filter(x_gray)
        
        return torch.cat([horizontal, vertical], dim=1)

# Simplified Feature Fusion
class SimpleFeatureFusion(nn.Module):
    def _init_(self):
        super(SimpleFeatureFusion, self)._init_()
        self.fusion = nn.Sequential(
            nn.Conv2d(5, 32, kernel_size=3, padding=1),  # 2 residual + 3 RGB
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        
    def forward(self, residual_features, rgb_features):
        fused = torch.cat([residual_features, rgb_features], dim=1)
        return self.fusion(fused)

# Simplified Classifier
class SimpleStegoClassifier(nn.Module):
    def _init_(self):
        super(SimpleStegoClassifier, self)._init_()
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        return self.classifier(x)

# Simplified Generator
class SimpleCoverGenerator(nn.Module):
    def _init_(self):
        super(SimpleCoverGenerator, self)._init_()
        self.generator = nn.Sequential(
            nn.Conv2d(64, 32, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )
        
    def forward(self, x):
        return self.generator(x)

# Simplified Dual Network
class SimpleDualNetwork(nn.Module):
    def __init__(self):
        super(SimpleDualNetwork, self).__init__()
        self.residual_extractor = SimpleResidualFeatureExtractor()
        self.feature_fusion = SimpleFeatureFusion()
        self.classifier = SimpleStegoClassifier()
        self.generator = SimpleCoverGenerator()
        
    def forward(self, x):
        residual_features = self.residual_extractor(x)
        fused_features = self.feature_fusion(residual_features, x)
        classification = self.classifier(fused_features)
        reconstruction = self.generator(fused_features)
        return classification, reconstruction, None


# Simplified Dataset
class SimpleStegoDataset(Dataset):
    def __init__(self, cover_dir, stego_dir, transform=None, max_samples=1000):
        self.cover_dir = cover_dir
        self.stego_dir = stego_dir
        self.transform = transform

        # Get limited number of samples for testing
        self.cover_images = sorted([f for f in os.listdir(cover_dir) 
                                   if f.endswith('.png')])[:max_samples]
        self.stego_images = sorted([f for f in os.listdir(stego_dir) 
                                   if f.endswith('.png')])[:max_samples]

        print(f"Using {len(self.cover_images)} samples for testing")

    def __len__(self):
        return len(self.cover_images)

    def __getitem__(self, idx):
        # Get cover image
        cover_name = self.cover_images[idx]
        cover_path = os.path.join(self.cover_dir, cover_name)

        # Get corresponding stego image (same filename)
        stego_name = self.stego_images[idx]
        stego_path = os.path.join(self.stego_dir, stego_name)

        # Load images
        cover_img = Image.open(cover_path).convert('RGB')
        stego_img = Image.open(stego_path).convert('RGB')

        if self.transform:
            cover_img = self.transform(cover_img)
            stego_img = self.transform(stego_img)

        return stego_img, cover_img, 1  # 1 indicates stego image

# Simplified Loss
class SimpleStegoLoss(nn.Module):
    def _init_(self):
        super(SimpleStegoLoss, self)._init_()
        self.classification_loss = nn.BCELoss()
        self.reconstruction_loss = nn.MSELoss()
        
    def forward(self, classification_pred, reconstruction, classification_target, reconstruction_target):
        cls_loss = self.classification_loss(classification_pred, classification_target)
        rec_loss = self.reconstruction_loss(reconstruction, reconstruction_target)
        total_loss = cls_loss + 0.5 * rec_loss  # Simple weighted sum
        return total_loss, cls_loss, rec_loss, 0

# Simplified Trainer
class SimpleStegoTrainer:
    def __init__(self, model, device, learning_rate=0.001):   # ✅ double underscores
        self.model = model.to(device)
        self.device = device
        self.optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        self.loss_fn = SimpleStegoLoss()
    
    def train_epoch(self, dataloader):
        self.model.train()
        total_loss, total_cls_loss, total_rec_loss = 0, 0, 0
        
        for batch_idx, (stego_imgs, cover_imgs, labels) in enumerate(dataloader):
            stego_imgs, cover_imgs, labels = (
                stego_imgs.to(self.device),
                cover_imgs.to(self.device),
                labels.float().to(self.device).unsqueeze(1)
            )
            
            # Forward pass
            classification_pred, reconstructed_cover, _ = self.model(stego_imgs)
            
            # Calculate loss
            loss, cls_loss, rec_loss, _ = self.loss_fn(
                classification_pred, reconstructed_cover, labels, cover_imgs
            )
            
            # Backward pass
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            
            # Accumulate losses
            total_loss += loss.item()
            total_cls_loss += cls_loss.item()
            total_rec_loss += rec_loss.item()
        
        return (total_loss / len(dataloader), 
                total_cls_loss / len(dataloader), 
                total_rec_loss / len(dataloader), 
                0)


# ==================== MAIN EXECUTION ====================
print("\n" + "="*60)
print("STARTING TRAINING WITH SIMPLIFIED MODEL")
print("="*60)

def main():
    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Simple transforms for testing
    transform = transforms.Compose([
        transforms.Resize((128, 128)),  # Smaller for testing
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    
    # Create small dataset for testing
    print("Creating small test dataset...")
    dataset = SimpleStegoDataset(cover_dir, stego_dir, transform, max_samples=100)
    
    # Split dataset
    train_size = int(0.8 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])
    
    # Create data loaders
    train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=4, shuffle=False)
    
    print(f"Training samples: {len(train_dataset)}")
    print(f"Validation samples: {len(val_dataset)}")
    
    # Initialize simple model
    print("Initializing simplified model...")
    model = SimpleDualNetwork().to(device)
    
    # Count parameters
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Total parameters: {total_params:,}")
    
    # Initialize trainer
    trainer = SimpleStegoTrainer(model, device, learning_rate=0.001)
    
    # Training loop - JUST 3 EPOCHS FOR TESTING
    num_epochs = 3
    print(f"\nStarting training for {num_epochs} epochs...")
    
    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch+1}/{num_epochs}")
        print("-" * 50)
        
        # Train for one epoch
        avg_loss, avg_cls_loss, avg_rec_loss, _ = trainer.train_epoch(train_dataloader)
        
        print(f"Training - Loss: {avg_loss:.4f}, CLS: {avg_cls_loss:.4f}, REC: {avg_rec_loss:.4f}")
        
        # Simple validation
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for stego_imgs, cover_imgs, labels in val_dataloader:
                stego_imgs, labels = stego_imgs.to(device), labels.to(device)
                classification_pred, _, _ = model(stego_imgs)
                pred_labels = (classification_pred > 0.5).float()
                correct += (pred_labels == labels).sum().item()
                total += labels.size(0)
            
            accuracy = correct / total
            print(f"Validation - Accuracy: {accuracy:.4f}")
    
    print("\nTraining completed successfully!")
    print("Model is working correctly!")
    
    # Save the model
    torch.save(model.state_dict(), "/kaggle/working/models/test_model.pth")
    print("Model saved to /kaggle/working/models/test_model.pth")

# Run the main function
if __name__ == "__main__":
    main()

print("\n" + "="*60)
print("PROGRAM COMPLETED SUCCESSFULLY!")
print("="*60)
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.11/dist-packages (1.5.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Using device: cuda
# GPU: Tesla P100-PCIE-16GB
# Found 20000 image files
# Split into 10000 cover and 10000 stego images
# Organized 10000 cover images and 10000 stego images
#
# After organization:
# Cover images: 10000
# Stego images: 10000
#
# Sample cover files:
#   00001.png
#   00002.png
#   00003.png
#   00004.png
#   00005.png
#
# Sample stego files:
#   00001.png
#   00002.png
#   00003.png
#   00004.png
#   00005.png
#
# Created mapping for 10000 image pairs
# Sample mappings:
#   00001.png → 00001.png
#   00002.png → 00002.png
#   00003.png → 00003.png
#   00004.png → 00004.png
#   00005.png → 00005.png
#
# Verifying mapping...
# ✓ 00001.png → 00001.png
# ✓ 00002.png → 00002.png
# ✓ 00003.png → 00003.png
# ✓ 00004.png → 00004.png
# ✓ 00005.png → 00005.png
# ✓ 00006.png → 00006.png
# ✓ 00007.png → 00007.png
# ✓ 00008.png → 00008.png
# ✓ 00009.png → 00009.png
# ✓ 00010.png → 00010.png
# ✓ All mappings are correct!
#
# ============================================================
# CREATING SIMPLIFIED MODEL FOR TESTING
# ============================================================
#
# ============================================================
# STARTING TRAINING WITH SIMPLIFIED MODEL
# ============================================================
# Using device: cuda
# Creating small test dataset...
# Using 100 samples for testing
# Training samples: 80
# Validation samples: 20
# Initializing simplified model...
# Total parameters: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_36/215665790.py in <cell line: 0>()
#     402 # Run the main function
#     403 if __name__ == "__main__":
# --> 404     main()
#     405
#     406 print("\n" + "="*60)
#
# /tmp/ipykernel_36/215665790.py in main()
#     363
#     364     # Initialize trainer
# --> 365     trainer = SimpleStegoTrainer(model, device, learning_rate=0.001)
#     366
#     367     # Training loop - JUST 3 EPOCHS FOR TESTING
#
# /tmp/ipykernel_36/215665790.py in __init__(self, model, device, learning_rate)
#     283         self.model = model.to(device)
#     284         self.device = device
# --> 285         self.optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#     286         self.loss_fn = SimpleStegoLoss()
#     287
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in __init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      97             fused=fused,
#      98         )
# ---> 99         super().__init__(params, defaults)
#     100
#     101         if fused:
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in __init__(self, params, defaults)
#     370         param_groups = list(params)
#     371         if len(param_groups) == 0:
# --> 372             raise ValueError("optimizer got an empty parameter list")
#     373         if not isinstance(param_groups[0], dict):
#     374             param_groups = [{"params": param_groups}]
#
# ValueError: optimizer got an empty parameter list

# %%
# First, install required packages
# !pip install torch torchvision pillow numpy scipy matplotlib scikit-learn tqdm

# Import libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix
import time
from tqdm import tqdm
import zipfile
from google.colab import files
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.8 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# Install required packages


# Import libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix
import time
from tqdm import tqdm
import zipfile
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Using device: cuda
# GPU: Tesla P100-PCIE-16GB

# %%
# Check what files are available
import os

# List files in the dataset
dataset_path = '/kaggle/input/bossbase'
print("Dataset contents:")
for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files[:5]:  # Show first 5 files
        print(f'{subindent}{file}')
    if len(files) > 5:
        print(f'{subindent}... and {len(files) - 5} more files')

# Check the actual structure - BOSSBase might have different organization
bossbase_files = []
for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.endswith(('.pgm', '.png', '.jpg', '.bmp')):
            bossbase_files.append(os.path.join(root, file))

print(f"\nFound {len(bossbase_files)} image files")
print("Sample files:", bossbase_files[:5])
# Out:
# Dataset contents:
# bossbase/
#   boss_256_0.4/
#     cover/
#       4353.png
#       7968.png
#       6490.png
#       5511.png
#       6262.png
#       ... and 8995 more files
#     stego/
#       4353.png
#       7968.png
#       6490.png
#       5511.png
#       6262.png
#       ... and 8995 more files
#   boss_256_0.4_test/
#     cover/
#       9273.png
#       9292.png
#       9703.png
#       9110.png
#       9938.png
#       ... and 995 more files
#     stego/
#       9273.png
#       9292.png
#       9703.png
#       9110.png
#       9938.png
#       ... and 995 more files
#
# Found 20000 image files
# Sample files: ['/kaggle/input/bossbase/boss_256_0.4/cover/4353.png', '/kaggle/input/bossbase/boss_256_0.4/cover/7968.png', '/kaggle/input/bossbase/boss_256_0.4/cover/6490.png', '/kaggle/input/bossbase/boss_256_0.4/cover/5511.png', '/kaggle/input/bossbase/boss_256_0.4/cover/6262.png']

# %%
# Create directories for organized dataset
# !mkdir -p /kaggle/working/data/cover
# !mkdir -p /kaggle/working/data/stego
# !mkdir -p /kaggle/working/models
# !mkdir -p /kaggle/working/results

# Organize the dataset - this depends on how the BOSSBase dataset is structured
# Typically, we need to separate cover and stego images

def organize_bossbase_dataset(input_path, cover_output, stego_output):
    """
    Organize BOSSBase dataset into cover and stego folders
    This function will need to be adjusted based on the actual dataset structure
    """
    all_image_files = []
    for root, dirs, files in os.walk(input_path):
        for file in files:
            if file.endswith(('.pgm', '.png', '.jpg', '.bmp', '.tiff')):
                all_image_files.append(os.path.join(root, file))
    
    print(f"Found {len(all_image_files)} image files to organize")
    
    # This is a guess - you'll need to adjust based on actual filenames
    # Typically, cover images might be named like "1.pgm" and stego like "1_S-UNIWARD.pgm"
    cover_count = 0
    stego_count = 0
    
    for img_path in all_image_files:
        filename = os.path.basename(img_path)
        
        # Heuristic to identify stego vs cover images
        # Adjust these conditions based on your actual filenames
        if any(keyword in filename.lower() for keyword in ['stego', 's-uniward', 'wow', 'hill', 'juniward']):
            # This is likely a stego image
            destination = os.path.join(stego_output, filename)
            stego_count += 1
        else:
            # This is likely a cover image
            destination = os.path.join(cover_output, filename)
            cover_count += 1
        
        # Copy the file
        # !cp "{img_path}" "{destination}"
    
    print(f"Organized {cover_count} cover images and {stego_count} stego images")
    return cover_count, stego_count

# Organize the dataset
cover_dir = '/kaggle/working/data/cover'
stego_dir = '/kaggle/working/data/stego'
cover_count, stego_count = organize_bossbase_dataset(dataset_path, cover_dir, stego_dir)

# If organization didn't work well, we might need manual inspection
print("\nFirst few cover files:")
# !ls -la "{cover_dir}" | head -5

print("\nFirst few stego files:")
# !ls -la "{stego_dir}" | head -5
# Out:
# Found 20000 image files to organize
# Organized 20000 cover images and 0 stego images
#
# First few cover files:
# total 113000
# drwxr-xr-x 2 root root 262144 Sep  5 10:36 .
# drwxr-xr-x 4 root root   4096 Sep  5 09:55 ..
# -rw-r--r-- 1 root root  13952 Sep  5 10:38 10000.png
# -rw-r--r-- 1 root root  11089 Sep  5 10:15 1000.png
# ls: write error: Broken pipe
#
# First few stego files:
# total 8
# drwxr-xr-x 2 root root 4096 Sep  5 09:55 .
# drwxr-xr-x 4 root root 4096 Sep  5 09:55 ..

# %%
# Create mapping between cover and stego files
# This is CRUCIAL for BOSSBase as filenames usually don't match directly

def create_filename_mapping(cover_dir, stego_dir):
    """
    Create mapping between cover and stego filenames
    """
    cover_files = sorted([f for f in os.listdir(cover_dir) 
                         if f.endswith(('.pgm', '.png', '.jpg', '.bmp', '.tiff'))])
    stego_files = sorted([f for f in os.listdir(stego_dir) 
                         if f.endswith(('.pgm', '.png', '.jpg', '.bmp', '.tiff'))])
    
    print(f"Cover files: {len(cover_files)}, Stego files: {len(stego_files)}")
    
    # Create mapping - this depends on the naming convention
    stego_to_cover_map = {}
    
    # Common BOSSBase pattern: cover: "1.pgm", stego: "1_S-UNIWARD.pgm"
    for stego_file in stego_files:
        # Try to find the corresponding cover file
        base_name = stego_file.split('_')[0]  # Get the number part
        cover_candidate = f"{base_name}.pgm"  # Assumes .pgm extension
        
        # Check if this cover file exists
        if cover_candidate in cover_files:
            stego_to_cover_map[cover_candidate] = stego_file
        else:
            # Try other extensions
            for ext in ['.png', '.jpg', '.bmp', '.tiff']:
                cover_candidate = f"{base_name}{ext}"
                if cover_candidate in cover_files:
                    stego_to_cover_map[cover_candidate] = stego_file
                    break
    
    print(f"Created mapping for {len(stego_to_cover_map)} image pairs")
    
    # Show some examples
    print("Sample mappings:")
    for i, (cover, stego) in enumerate(list(stego_to_cover_map.items())[:5]):
        print(f"  {cover} → {stego}")
    
    return stego_to_cover_map

# Create filename mapping
stego_to_cover_map = create_filename_mapping(cover_dir, stego_dir)
# Out:
# Cover files: 10000, Stego files: 0
# Created mapping for 0 image pairs
# Sample mappings:

# %%
# ==================== FEATURE EXTRACTION ====================
class ResidualFeatureExtractor(nn.Module):
    def __init__(self):
        super(ResidualFeatureExtractor, self).__init__()
        self.srm_filters = self._create_srm_filters()
        
    def _create_srm_filters(self):
        filters = []
        for angle in [0, 45, 90, 135]:
            filter_size = 5
            filt = np.zeros((filter_size, filter_size))
            center = filter_size // 2
            
            if angle == 0:  # Horizontal
                filt[center, :] = 1
                filt[center, center] = -filter_size + 1
            elif angle == 90:  # Vertical
                filt[:, center] = 1
                filt[center, center] = -filter_size + 1
            elif angle == 45:  # Diagonal
                for i in range(filter_size):
                    filt[i, i] = 1
                filt[center, center] = -filter_size + 1
            elif angle == 135:  # Anti-diagonal
                for i in range(filter_size):
                    filt[i, filter_size-1-i] = 1
                filt[center, center] = -filter_size + 1
            
            filters.append(filt)
        
        filters = [torch.FloatTensor(filt).unsqueeze(0).unsqueeze(0) for filt in filters]
        return nn.ModuleList([nn.Conv2d(1, 1, kernel_size=5, padding=2, bias=False) for _ in range(len(filters))])
    
    def forward(self, x):
        if x.shape[1] == 3:
            x_gray = 0.299 * x[:, 0:1, :, :] + 0.587 * x[:, 1:2, :, :] + 0.114 * x[:, 2:3, :, :]
        else:
            x_gray = x
        
        residuals = []
        for i, filter_layer in enumerate(self.srm_filters):
            residual = filter_layer(x_gray)
            residuals.append(residual)
        
        return torch.cat(residuals, dim=1)

class FeatureFusion(nn.Module):
    def __init__(self, residual_channels=4, rgb_channels=3):
        super(FeatureFusion, self).__init__()
        self.residual_conv = nn.Sequential(
            nn.Conv2d(residual_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)
        )
        self.rgb_conv = nn.Sequential(
            nn.Conv2d(rgb_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)
        )
        self.fusion_conv = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        
    def forward(self, residual_features, rgb_features):
        residual_processed = self.residual_conv(residual_features)
        rgb_processed = self.rgb_conv(rgb_features)
        fused = torch.cat([residual_processed, rgb_processed], dim=1)
        return self.fusion_conv(fused)

# ==================== ATTENTION NETWORK ====================
class ResidualAttentionModule(nn.Module):
    def __init__(self, in_channels, reduction_ratio=16):
        super(ResidualAttentionModule, self).__init__()
        self.in_channels = in_channels
        self.reduction_ratio = reduction_ratio
        
        self.channel_attention = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(in_channels, in_channels // reduction_ratio, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels // reduction_ratio, in_channels, kernel_size=1),
            nn.Sigmoid()
        )
        self.spatial_attention = nn.Sequential(
            nn.Conv2d(in_channels, in_channels // reduction_ratio, kernel_size=1),
            nn.BatchNorm2d(in_channels // reduction_ratio),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels // reduction_ratio, 1, kernel_size=1),
            nn.Sigmoid()
        )
        self.filter_gate = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(in_channels, in_channels * 2),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels * 2, in_channels),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        batch_size, channels, height, width = x.shape
        channel_weights = self.channel_attention(x)
        spatial_weights = self.spatial_attention(x)
        filter_weights = self.filter_gate(x).view(batch_size, channels, 1, 1)
        attention_weights = channel_weights * spatial_weights * filter_weights
        attended_features = x * attention_weights
        return x + attended_features, attention_weights

class ResidualAttentionNetwork(nn.Module):
    def __init__(self, in_channels, num_attention_blocks=3):
        super(ResidualAttentionNetwork, self).__init__()
        self.initial_conv = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        self.attention_blocks = nn.ModuleList()
        for i in range(num_attention_blocks):
            self.attention_blocks.append(ResidualAttentionModule(64))
        self.final_conv = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        
    def forward(self, x):
        features = self.initial_conv(x)
        attention_maps = []
        for attention_block in self.attention_blocks:
            features, attention_weights = attention_block(features)
            attention_maps.append(attention_weights)
        features = self.final_conv(features)
        return features, attention_maps

# ==================== DUAL-ADVERSARIAL NETWORK ====================
class StegoClassifier(nn.Module):
    def __init__(self, in_channels):
        super(StegoClassifier, self).__init__()
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(in_channels, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.AdaptiveAvgPool2d(1)
        )
        self.classifier = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        features = self.feature_extractor(x)
        features = features.view(features.size(0), -1)
        return self.classifier(features)

class CoverGenerator(nn.Module):
    def __init__(self, in_channels, out_channels=3):
        super(CoverGenerator, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 128, kernel_size=3, padding=1, stride=2),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 256, kernel_size=3, padding=1, stride=2),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, out_channels, kernel_size=3, padding=1),
            nn.Tanh()
        )
        
    def forward(self, x):
        encoded = self.encoder(x)
        return self.decoder(encoded)

class ConsistencyChecker(nn.Module):
    def __init__(self):
        super(ConsistencyChecker, self).__init__()
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(6, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.AdaptiveAvgPool2d(1)
        )
        self.consistency_predictor = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )
        
    def forward(self, original, reconstructed):
        combined = torch.cat([original, reconstructed], dim=1)
        features = self.feature_extractor(combined)
        features = features.view(features.size(0), -1)
        return self.consistency_predictor(features)

class DualAdversarialNetwork(nn.Module):
    def __init__(self, in_channels):
        super(DualAdversarialNetwork, self).__init__()
        self.classifier = StegoClassifier(in_channels)
        self.generator = CoverGenerator(in_channels)
        self.consistency_checker = ConsistencyChecker()
        
    def forward(self, x, original_image=None):
        classification = self.classifier(x)
        reconstructed_cover = self.generator(x)
        consistency_score = None
        if original_image is not None:
            original_normalized = (original_image - 0.5) * 2
            consistency_score = self.consistency_checker(original_normalized, reconstructed_cover)
        return classification, reconstructed_cover, consistency_score

# ==================== DATASET AND TRAINING ====================
class StegoDataset(Dataset):
    def __init__(self, cover_dir, stego_dir, stego_to_cover_map=None, transform=None):
        self.cover_dir = cover_dir
        self.stego_dir = stego_dir
        self.transform = transform
        self.stego_to_cover_map = stego_to_cover_map
        
        # Get list of images
        self.cover_images = sorted([f for f in os.listdir(cover_dir) 
                                  if f.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.pgm', '.tiff'))])
        
        if stego_to_cover_map:
            # Use the mapping to find corresponding stego images
            self.stego_images = [stego_to_cover_map[cover] for cover in self.cover_images 
                               if cover in stego_to_cover_map]
            # Filter cover images to only those with matching stego
            self.cover_images = [cover for cover in self.cover_images 
                               if cover in stego_to_cover_map]
        else:
            # Assume filenames match exactly
            self.stego_images = sorted([f for f in os.listdir(stego_dir) 
                                      if f.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.pgm', '.tiff'))])
            
            # Verify they match
            if len(self.cover_images) != len(self.stego_images):
                print("Warning: Number of cover and stego images don't match!")
            
            # For BOSSBase, sometimes we need to ensure matching
            if not all(c == s for c, s in zip(self.cover_images, self.stego_images)):
                print("Warning: Cover and stego filenames don't match exactly!")
                print("Consider providing a stego_to_cover_map")
    
    def __len__(self):
        return min(len(self.cover_images), len(self.stego_images))
    
    def __getitem__(self, idx):
        # Get cover image
        cover_name = self.cover_images[idx]
        cover_path = os.path.join(self.cover_dir, cover_name)
        
        # Handle different image formats
        try:
            cover_img = Image.open(cover_path).convert('RGB')
        except:
            # Try different approaches for .pgm files
            if cover_path.endswith('.pgm'):
                cover_img = Image.open(cover_path)
                cover_img = cover_img.convert('RGB')
            else:
                raise ValueError(f"Could not open image: {cover_path}")
        
        # Get corresponding stego image
        if self.stego_to_cover_map:
            stego_name = self.stego_to_cover_map[cover_name]
        else:
            stego_name = self.stego_images[idx]
        stego_path = os.path.join(self.stego_dir, stego_name)
        
        try:
            stego_img = Image.open(stego_path).convert('RGB')
        except:
            if stego_path.endswith('.pgm'):
                stego_img = Image.open(stego_path)
                stego_img = stego_img.convert('RGB')
            else:
                raise ValueError(f"Could not open image: {stego_path}")
        
        if self.transform:
            cover_img = self.transform(cover_img)
            stego_img = self.transform(stego_img)
        
        return stego_img, cover_img, 1  # 1 indicates stego image

class StegoLoss(nn.Module):
    def __init__(self, alpha=1.0, beta=0.5, gamma=0.1):
        super(StegoLoss, self).__init__()
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.classification_loss = nn.BCELoss()
        self.reconstruction_loss = nn.MSELoss()
        self.consistency_loss = nn.BCELoss()
    
    def forward(self, classification_pred, reconstruction, consistency_pred, 
                classification_target, reconstruction_target, consistency_target=None):
        cls_loss = self.classification_loss(classification_pred, classification_target)
        rec_loss = self.reconstruction_loss(reconstruction, reconstruction_target)
        cons_loss = 0
        if consistency_target is not None and consistency_pred is not None:
            cons_loss = self.consistency_loss(consistency_pred, consistency_target)
        total_loss = (self.alpha * cls_loss + self.beta * rec_loss + self.gamma * cons_loss)
        return total_loss, cls_loss, rec_loss, cons_loss

class StegoTrainer:
    def __init__(self, model, device, learning_rate=0.001):
        self.model = model.to(device)
        self.device = device
        self.optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        self.scheduler = optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, patience=5, factor=0.5)
        self.loss_fn = StegoLoss(alpha=1.0, beta=0.5, gamma=0.1)
    
    def train_epoch(self, dataloader):
        self.model.train()
        total_loss, total_cls_loss, total_rec_loss, total_cons_loss = 0, 0, 0, 0
        
        for batch_idx, (stego_imgs, cover_imgs, labels) in enumerate(tqdm(dataloader, desc="Training")):
            stego_imgs, cover_imgs, labels = stego_imgs.to(self.device), cover_imgs.to(self.device), labels.float().to(self.device).unsqueeze(1)
            
            # Extract features
            residual_extractor = ResidualFeatureExtractor().to(self.device)
            residual_features = residual_extractor(stego_imgs)
            
            feature_fusion = FeatureFusion().to(self.device)
            fused_features = feature_fusion(residual_features, stego_imgs)
            
            # Apply attention
            attention_net = ResidualAttentionNetwork(in_channels=64).to(self.device)
            attended_features, _ = attention_net(fused_features)
            
            # Forward pass through DAN
            classification_pred, reconstructed_cover, consistency_pred = self.model(attended_features, stego_imgs)
            
            # Calculate loss
            loss, cls_loss, rec_loss, cons_loss = self.loss_fn(
                classification_pred, reconstructed_cover, consistency_pred,
                labels, cover_imgs, torch.ones_like(consistency_pred) if consistency_pred is not None else None
            )
            
            # Backward pass
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
            
            # Accumulate losses
            total_loss += loss.item()
            total_cls_loss += cls_loss.item()
            total_rec_loss += rec_loss.item()
            if cons_loss != 0:
                total_cons_loss += cons_loss.item()
        
        return (total_loss / len(dataloader), 
                total_cls_loss / len(dataloader), 
                total_rec_loss / len(dataloader), 
                total_cons_loss / len(dataloader) if total_cons_loss > 0 else 0)
    
    def validate(self, dataloader):
        self.model.eval()
        total_loss, correct, total = 0, 0, 0
        all_predictions, all_labels = [], []
        
        with torch.no_grad():
            for stego_imgs, cover_imgs, labels in tqdm(dataloader, desc="Validation"):
                stego_imgs, cover_imgs, labels = stego_imgs.to(self.device), cover_imgs.to(self.device), labels.float().to(self.device).unsqueeze(1)
                
                # Extract features
                residual_extractor = ResidualFeatureExtractor().to(self.device)
                residual_features = residual_extractor(stego_imgs)
                
                feature_fusion = FeatureFusion().to(self.device)
                fused_features = feature_fusion(residual_features, stego_imgs)
                
                # Apply attention
                attention_net = ResidualAttentionNetwork(in_channels=64).to(self.device)
                attended_features, _ = attention_net(fused_features)
                
                # Forward pass
                classification_pred, reconstructed_cover, consistency_pred = self.model(attended_features, stego_imgs)
                
                # Calculate loss
                loss, _, _, _ = self.loss_fn(
                    classification_pred, reconstructed_cover, consistency_pred,
                    labels, cover_imgs, torch.ones_like(consistency_pred) if consistency_pred is not None else None
                )
                
                total_loss += loss.item()
                
                # Calculate accuracy
                pred_labels = (classification_pred > 0.5).float()
                correct += (pred_labels == labels).sum().item()
                total += labels.size(0)
                
                # Store for ROC calculation
                all_predictions.extend(classification_pred.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        # Calculate ROC curve
        all_predictions, all_labels = np.array(all_predictions), np.array(all_labels)
        fpr, tpr, _ = roc_curve(all_labels, all_predictions)
        roc_auc = auc(fpr, tpr)
        
        return total_loss / len(dataloader), correct / total, fpr, tpr, roc_auc, all_predictions, all_labels

def plot_training_history(train_losses, val_losses, val_accuracies, roc_info):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))
    
    # Plot training and validation loss
    ax1.plot(train_losses, label='Training Loss')
    ax1.plot(val_losses, label='Validation Loss')
    ax1.set_title('Training and Validation Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True)
    
    # Plot validation accuracy
    ax2.plot(val_accuracies, label='Validation Accuracy', color='green')
    ax2.set_title('Validation Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend()
    ax2.grid(True)
    
    # Plot ROC curve
    fpr, tpr, roc_auc = roc_info[:3]
    ax3.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    ax3.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax3.set_xlim([0.0, 1.0])
    ax3.set_ylim([0.0, 1.05])
    ax3.set_xlabel('False Positive Rate')
    ax3.set_ylabel('True Positive Rate')
    ax3.set_title('Receiver Operating Characteristic')
    ax3.legend(loc="lower right")
    ax3.grid(True)
    
    # Calculate confusion matrix
    if len(roc_info) > 5:
        all_predictions, all_labels = roc_info[5], roc_info[6]
        cm = confusion_matrix(all_labels, (all_predictions > 0.5).astype(int))
        ax4.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        ax4.set_title('Confusion Matrix')
        ax4.set_ylabel('True label')
        ax4.set_xlabel('Predicted label')
        tick_marks = np.arange(2)
        ax4.set_xticks(tick_marks)
        ax4.set_yticks(tick_marks)
        ax4.set_xticklabels(['Cover', 'Stego'])
        ax4.set_yticklabels(['Cover', 'Stego'])
        
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                ax4.text(j, i, format(cm[i, j], 'd'),
                        ha="center", va="center",
                        color="white" if cm[i, j] > thresh else "black")
    
    plt.tight_layout()
    plt.savefig('/kaggle/working/results/training_results.png')
    plt.show()
